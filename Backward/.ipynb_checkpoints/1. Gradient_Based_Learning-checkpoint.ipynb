# %%
import numpy as np
import matplotlib.pyplot as plt
import torch 
import torch.nn as nn

# %%
function_x = np.linspace(-3,3,100)
function_y = 2*function_x ** 2

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(function_x, function_y)

x = 3
y = 2*x**2
ax .scatter(x,y, color='blue')  # start Point
lr = 0.4                        

for _ in range(30):
    dy_dx = 4 * x              # differential Coefficient
    x = x- lr*(dy_dx)          # update
    y = 2*x**2
    
    ax .scatter(x,y, color='red')

# %%
function_x = np.linspace(-3,3,100)
function_y = 2*function_x ** 2

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(function_x, function_y)

x = 3
y = 2*x**2
ax .scatter(x,y, color='blue')  # start Point
lr = 0.05

for _ in range(30):
    dy_dx = 4 * x
    x = x- lr*(dy_dx)
    y = 2*x**2
    
    ax .scatter(x,y, color='red')

# %%
function_x = np.linspace(-3,3,100)
function_y = 2*function_x ** 2

fig, ax = plt.subplots(figsize=(10,5))
ax.plot(function_x, function_y)

x = 3
y = 2*x**2
ax .scatter(x,y, color='blue', s=100)  # start Point
lr = 0.6                               # Too High Learning Rate -> divergence

for _ in range(30):
    dy_dx = 4 * x              # differential Coefficient
    x = x- lr*(dy_dx)          # update
    y = 2*x**2
    
    ax .scatter(x,y, color='red')
